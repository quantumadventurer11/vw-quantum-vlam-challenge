# %%
# %%bash
# apt-get install -y -q --fix-missing texlive-latex-extra texlive-science 2>&1 | tail -8
# which pdflatex && pdflatex --version | head -1

# %%
# %%bash
# git clone --depth 1 https://github.com/quantumadventurer11/vw-quantum-vlam-challenge.git /tmp/vlam
# echo "report.tex size: $(wc -c < /tmp/vlam/docs/report.tex) bytes"
# grep -c '5881' /tmp/vlam/docs/report.tex && echo 'real GPU numbers present' || echo 'WARNING: real GPU numbers not found'
# ls /tmp/vlam/results/*.png 2>/dev/null || echo 'WARNING: no PNG figures found'

# %%
# %%bash
# cd /tmp/vlam/docs
# rm -f report.pdf
# echo '=== Pass 1 ==='
# pdflatex -interaction=nonstopmode report.tex || true
# echo '=== Pass 2 ==='
# pdflatex -interaction=nonstopmode report.tex || true
# if [ ! -f report.pdf ]; then echo 'ERROR: pdflatex produced no PDF'; exit 1; fi
# ls -lh report.pdf
# cp report.pdf /kaggle/working/report.pdf
# echo "Done: $(ls -lh /kaggle/working/report.pdf)"

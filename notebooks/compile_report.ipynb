# %%
# %%bash
# apt-get install -y -q texlive-latex-extra texlive-science 2>&1 | tail -5

# %%
# %%bash
# git clone --depth 1 https://github.com/quantumadventurer11/vw-quantum-vlam-challenge.git /tmp/vlam
# echo "Cloned. report.tex size: $(wc -c < /tmp/vlam/docs/report.tex) bytes"

# %%
# %%bash
# cd /tmp/vlam/docs
# pdflatex -interaction=nonstopmode report.tex 2>&1 | grep -E 'Error|Warning|error|Output written' | head -30
# pdflatex -interaction=nonstopmode report.tex 2>&1 | grep -E 'Error|Warning|error|Output written' | head -10
# echo "--- Second pass done ---"
# cp report.pdf /kaggle/working/report.pdf
# ls -lh /kaggle/working/report.pdf
